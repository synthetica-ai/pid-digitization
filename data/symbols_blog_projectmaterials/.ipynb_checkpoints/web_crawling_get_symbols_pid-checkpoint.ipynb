# %% [markdown]
# # Download images
# from https://blog.projectmaterials.com/instrumentation/pid-symbols/
#
# and
#
# from https://www.pipingengineer.org/images/symbols/

# %% [markdown]
# ## Instruments

# %%
pwd
# Out:
# '/home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob'

# %%
cd INSTRUMENTS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/INSTRUMENTS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_instru/'
# Out:
# --2021-08-17 21:08:41--  https://www.pipingengineer.org/images/symbols/pid_instru/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_instru/index.html.tmp’
#
# www.pipingengineer.     [  <=>               ]  16.21K  43.9KB/s    in 0.4s
#
# 2021-08-17 21:08:42 (43.9 KB/s) - ‘www.pipingengineer.org/images/symbols/pid_instru/index.html.tmp’ saved [16601]
#
# Loading robots.txt; please ignore errors.
# --2021-08-17 21:08:42--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Pumps

# %%
cd ../PUMPS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/PUMPS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_pumps/'
# Out:
# --2021-08-18 07:43:41--  https://www.pipingengineer.org/images/symbols/pid_pumps/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7139 (7.0K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_pumps/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   6.97K  --.-KB/s    in 0s
#
# 2021-08-18 07:43:42 (555 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_pumps/index.html.tmp’ saved [7139/7139]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 07:43:42--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Compressors

# %%
cd ../COMPRESSORS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/COMPRESSORS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_compressors/'
# Out:
# --2021-08-18 07:45:24--  https://www.pipingengineer.org/images/symbols/pid_compressors/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6094 (6.0K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_compressors/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   5.95K  --.-KB/s    in 0s
#
# 2021-08-18 07:45:25 (243 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_compressors/index.html.tmp’ saved [6094/6094]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 07:45:25--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Vessels

# %%
cd ../VESSELS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/VESSELS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_vessels/'
# Out:
# --2021-08-18 07:46:25--  https://www.pipingengineer.org/images/symbols/pid_vessels/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_vessels/index.html.tmp’
#
# www.pipingengineer.     [ <=>                ]   8.08K  --.-KB/s    in 0s
#
# 2021-08-18 07:46:26 (85.5 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_vessels/index.html.tmp’ saved [8277]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 07:46:26--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Motors, Generators, Turbines

# %%
cd ../MOTORS_GENERATORS_TURBINES
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/MOTORS_GENERATORS_TURBINES

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_motors/'
# Out:
# --2021-08-18 07:47:48--  https://www.pipingengineer.org/images/symbols/pid_motors/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3777 (3.7K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_motors/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   3.69K  --.-KB/s    in 0s
#
# 2021-08-18 07:47:49 (158 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_motors/index.html.tmp’ saved [3777/3777]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 07:47:49--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Dryers

# %%
cd ../DRYERS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/DRYERS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_dryers/'
# Out:
# --2021-08-18 08:12:53--  https://www.pipingengineer.org/images/symbols/pid_dryers/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1965 (1.9K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_dryers/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   1.92K  --.-KB/s    in 0s
#
# 2021-08-18 08:12:54 (91.2 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_dryers/index.html.tmp’ saved [1965/1965]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:12:54--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Centrifuges

# %%
cd ..
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob

# %%
mkdir CENTRIFUGES

# %%
cd ../CENTRIFUGES
# Out:
# [Errno 2] No such file or directory: '../CENTRIFUGES'
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_centrifuges/'
# Out:
# --2021-08-18 08:14:32--  https://www.pipingengineer.org/images/symbols/pid_centrifuges/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2235 (2.2K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_centrifuges/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   2.18K  --.-KB/s    in 0s
#
# 2021-08-18 08:14:33 (87.3 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_centrifuges/index.html.tmp’ saved [2235/2235]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:14:33--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Crushers

# %%
ls
# Out:
# CENTRIFUGES/  FILTERS/                     PUMPS/
# COMPRESSORS/  INSTRUMENTS/                 VALVES/
# CRUSHERS/     MOTORS_GENERATORS_TURBINES/  VESSELS/
# DRYERS/       PIPING/                      web_crawling_get_symbols_pid.ipynb

# %%
cd symbols_blob
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob

# %%
cd CRUSHERS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/CRUSHERS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_crushers/'
# Out:
# --2021-08-18 08:18:51--  https://www.pipingengineer.org/images/symbols/pid_crushers/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2890 (2.8K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_crushers/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2021-08-18 08:18:52 (126 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_crushers/index.html.tmp’ saved [2890/2890]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:18:52--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Exchangers

# %%
cd EXCHANGERS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/EXCHANGERS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_exchangers/'
# Out:
# --2021-08-18 08:20:32--  https://www.pipingengineer.org/images/symbols/pid_exchangers/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_exchangers/index.html.tmp’
#
# www.pipingengineer.     [ <=>                ]  10.57K  --.-KB/s    in 0s
#
# 2021-08-18 08:20:32 (65.3 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_exchangers/index.html.tmp’ saved [10827]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:20:32--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Handling

# %%
mkdir ../HANDLING

# %%
cd ../HANDLING
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/HANDLING

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_handling/'
# Out:
# --2021-08-18 08:22:01--  https://www.pipingengineer.org/images/symbols/pid_handling/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5668 (5.5K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_handling/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   5.54K  --.-KB/s    in 0s
#
# 2021-08-18 08:22:02 (270 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_handling/index.html.tmp’ saved [5668/5668]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:22:02--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Markings

# %%
mkdir ../MARKINGS

# %%
cd ../MARKINGS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/MARKINGS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_markings/'
# Out:
# --2021-08-18 08:23:32--  https://www.pipingengineer.org/images/symbols/pid_markings/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7196 (7.0K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_markings/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   7.03K  --.-KB/s    in 0s
#
# 2021-08-18 08:23:33 (328 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_markings/index.html.tmp’ saved [7196/7196]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:23:33--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Mixers

# %%
mkdir ../MIXERS

# %%
cd ../MIXERS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/MIXERS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_mixers/'
# Out:
# --2021-08-18 08:24:12--  https://www.pipingengineer.org/images/symbols/pid_mixers/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3282 (3.2K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_mixers/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   3.21K  --.-KB/s    in 0s
#
# 2021-08-18 08:24:13 (189 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_mixers/index.html.tmp’ saved [3282/3282]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:24:13--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Motors

# %%
mkdir ../MOTORS

# %%
cd ../MOTORS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/MOTORS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_motors/'
# Out:
# --2021-08-18 08:25:02--  https://www.pipingengineer.org/images/symbols/pid_motors/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3777 (3.7K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_motors/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   3.69K  --.-KB/s    in 0s
#
# 2021-08-18 08:25:03 (142 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_motors/index.html.tmp’ saved [3777/3777]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:25:03--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Others

# %%
mkdir ../OTHERS

# %%
cd ../OTHERS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/OTHERS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_others/'
# Out:
# --2021-08-18 08:26:52--  https://www.pipingengineer.org/images/symbols/pid_others/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_others/index.html.tmp’
#
# www.pipingengineer.     [ <=>                ]   9.21K  --.-KB/s    in 0s
#
# 2021-08-18 08:26:53 (59.0 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_others/index.html.tmp’ saved [9433]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:26:53--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Reactors

# %%
mkdir ../REACTORS

# %%
cd ../REACTORS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/REACTORS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_reactors/'
# Out:
# --2021-08-18 08:28:01--  https://www.pipingengineer.org/images/symbols/pid_reactors/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2163 (2.1K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_reactors/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   2.11K  --.-KB/s    in 0s
#
# 2021-08-18 08:28:02 (128 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_reactors/index.html.tmp’ saved [2163/2163]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:28:02--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Special items

# %%
mkdir ../SPECIAL_ITEMS

# %%
cd ../SPECIAL_ITEMS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/SPECIAL_ITEMS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/pid_special_items/'
# Out:
# --2021-08-18 08:28:59--  https://www.pipingengineer.org/images/symbols/pid_special_items/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5500 (5.4K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/pid_special_items/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   5.37K  --.-KB/s    in 0s
#
# 2021-08-18 08:29:00 (228 MB/s) - ‘www.pipingengineer.org/images/symbols/pid_special_items/index.html.tmp’ saved [5500/5500]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:29:00--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Iso valves

# %%
mkdir ../VALVES_ISO

# %%
cd ../VALVES_ISO
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/VALVES_ISO

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/iso_valves/'
# Out:
# --2021-08-18 08:31:47--  https://www.pipingengineer.org/images/symbols/iso_valves/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6328 (6.2K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/iso_valves/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   6.18K  --.-KB/s    in 0s
#
# 2021-08-18 08:31:48 (393 MB/s) - ‘www.pipingengineer.org/images/symbols/iso_valves/index.html.tmp’ saved [6328/6328]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:31:48--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Iso SP items

# %%
mkdir ../ISO_SP_ITEMS

# %%
cd ../ISO_SP_ITEMS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/ISO_SP_ITEMS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/iso_sp_items/'
# Out:
# --2021-08-18 08:33:13--  https://www.pipingengineer.org/images/symbols/iso_sp_items/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2151 (2.1K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/iso_sp_items/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   2.10K  --.-KB/s    in 0s
#
# 2021-08-18 08:33:14 (129 MB/s) - ‘www.pipingengineer.org/images/symbols/iso_sp_items/index.html.tmp’ saved [2151/2151]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:33:14--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Iso fittings

# %%
mkdir ../ISO_FITTINGS

# %%
cd ../ISO_FITTINGS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/ISO_FITTINGS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/iso_fittings/'
# Out:
# --2021-08-18 08:34:48--  https://www.pipingengineer.org/images/symbols/iso_fittings/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5995 (5.9K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/iso_fittings/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   5.85K  --.-KB/s    in 0s
#
# 2021-08-18 08:34:49 (274 MB/s) - ‘www.pipingengineer.org/images/symbols/iso_fittings/index.html.tmp’ saved [5995/5995]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:34:49--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Iso markings

# %%
mkdir ../ISO_MARKINGS

# %%
cd ../ISO_MARKINGS
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/ISO_MARKINGS

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/iso_markings/'
# Out:
# --2021-08-18 08:36:14--  https://www.pipingengineer.org/images/symbols/iso_markings/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1407 (1.4K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/iso_markings/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   1.37K  --.-KB/s    in 0s
#
# 2021-08-18 08:36:15 (43.1 MB/s) - ‘www.pipingengineer.org/images/symbols/iso_markings/index.html.tmp’ saved [1407/1407]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:36:15--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %% [markdown]
# ## Welding

# %%
mkdir ../WELDING

# %%
cd ../WELDING
# Out:
# /home/jovyan/mezcla/Documents/Data_Science/capstone/pid-digitization/data/symbols_blob/WELDING

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/welding_arrow_side/'
# Out:
# --2021-08-18 08:38:03--  https://www.pipingengineer.org/images/symbols/welding_arrow_side/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3921 (3.8K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/welding_arrow_side/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   3.83K  --.-KB/s    in 0s
#
# 2021-08-18 08:38:04 (155 MB/s) - ‘www.pipingengineer.org/images/symbols/welding_arrow_side/index.html.tmp’ saved [3921/3921]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:38:04--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/welding_both_sides/'
# Out:
# --2021-08-18 08:38:12--  https://www.pipingengineer.org/images/symbols/welding_both_sides/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2376 (2.3K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/welding_both_sides/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   2.32K  --.-KB/s    in 0s
#
# 2021-08-18 08:38:13 (59.8 MB/s) - ‘www.pipingengineer.org/images/symbols/welding_both_sides/index.html.tmp’ saved [2376/2376]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:38:13--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/welding_other_side/'
# Out:
# --2021-08-18 08:38:19--  https://www.pipingengineer.org/images/symbols/welding_other_side/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3539 (3.5K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/welding_other_side/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   3.46K  --.-KB/s    in 0s
#
# 2021-08-18 08:38:20 (324 MB/s) - ‘www.pipingengineer.org/images/symbols/welding_other_side/index.html.tmp’ saved [3539/3539]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:38:20--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...

# %%
! wget -r -np -A '*.jpg' 'https://www.pipingengineer.org/images/symbols/welding_extra_symbols/'
# Out:
# --2021-08-18 08:38:28--  https://www.pipingengineer.org/images/symbols/welding_extra_symbols/
# Resolving www.pipingengineer.org (www.pipingengineer.org)... 192.185.129.139
# Connecting to www.pipingengineer.org (www.pipingengineer.org)|192.185.129.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2958 (2.9K) [text/html]
# Saving to: ‘www.pipingengineer.org/images/symbols/welding_extra_symbols/index.html.tmp’
#
# www.pipingengineer. 100%[===================>]   2.89K  --.-KB/s    in 0s
#
# 2021-08-18 08:38:29 (58.7 MB/s) - ‘www.pipingengineer.org/images/symbols/welding_extra_symbols/index.html.tmp’ saved [2958/2958]
#
# Loading robots.txt; please ignore errors.
# --2021-08-18 08:38:29--  https://www.pipingengineer.org/robots.txt
# Reusing existing connection to www.pipingengineer.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘www.pipingengineer.org/robots.txt.tmp’
#
# ...
